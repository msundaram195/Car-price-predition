# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
cars_data=pd.read_csv('cars_sampled.csv')

# %%
cars=cars_data.copy()

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50001 entries, 0 to 50000
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50001 non-null  object
#  1   name                 50001 non-null  object
#  2   seller               50001 non-null  object
#  3   offerType            50001 non-null  object
#  4   price                50001 non-null  int64
#  5   abtest               50001 non-null  object
#  6   vehicleType          44813 non-null  object
#  7   yearOfRegistration   50001 non-null  int64
#  8   gearbox              47177 non-null  object
#  9   powerPS              50001 non-null  int64
#  10  model                47243 non-null  object
#  11  kilometer            50001 non-null  int64
#  12  monthOfRegistration  50001 non-null  int64
#  13  fuelType             45498 non-null  object
#  14  brand                50001 non-null  object
#  15  notRepairedDamage    40285 non-null  object
#  16  dateCreated          50001 non-null  object
#  17  postalCode           50001 non-null  int64
#  18  lastSeen             50001 non-null  object
# dtypes: int64(6), object(13)
# memory usage: 7.2+ MB

# %%
cars.describe()
# Out:
#               price  yearOfRegistration       powerPS      kilometer  \
# count  5.000100e+04        50001.000000  50001.000000   50001.000000
# mean   6.559865e+03         2005.544229    116.496130  125613.687726
# std    8.581847e+04          122.991832    230.567709   40205.234483
# min    0.000000e+00         1000.000000      0.000000    5000.000000
# 25%    1.150000e+03         1999.000000     69.000000  125000.000000
# 50%    2.950000e+03         2003.000000    105.000000  150000.000000
# 75%    7.190000e+03         2008.000000    150.000000  150000.000000
# max    1.234568e+07         9999.000000  19312.000000  150000.000000
#
#        monthOfRegistration    postalCode
# count         50001.000000  50001.000000
# mean              5.743725  50775.216696
# std               3.711345  25743.701933
# min               0.000000   1067.000000
# 25%               3.000000  30559.000000
# 50%               6.000000  49504.000000
# 75%               9.000000  71404.000000
# max              12.000000  99998.000000

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
cars.describe()
# Out:
#              price  yearOfRegistration   powerPS  kilometer  \
# count    50001.000           50001.000 50001.000  50001.000
# mean      6559.865            2005.544   116.496 125613.688
# std      85818.470             122.992   230.568  40205.234
# min          0.000            1000.000     0.000   5000.000
# 25%       1150.000            1999.000    69.000 125000.000
# 50%       2950.000            2003.000   105.000 150000.000
# 75%       7190.000            2008.000   150.000 150000.000
# max   12345678.000            9999.000 19312.000 150000.000
#
#        monthOfRegistration  postalCode
# count            50001.000   50001.000
# mean                 5.744   50775.217
# std                  3.711   25743.702
# min                  0.000    1067.000
# 25%                  3.000   30559.000
# 50%                  6.000   49504.000
# 75%                  9.000   71404.000
# max                 12.000   99998.000

# %%
pd.set_option('display.max_columns',500)

# %%
cars.describe()
# Out:
#              price  yearOfRegistration   powerPS  kilometer  \
# count    50001.000           50001.000 50001.000  50001.000
# mean      6559.865            2005.544   116.496 125613.688
# std      85818.470             122.992   230.568  40205.234
# min          0.000            1000.000     0.000   5000.000
# 25%       1150.000            1999.000    69.000 125000.000
# 50%       2950.000            2003.000   105.000 150000.000
# 75%       7190.000            2008.000   150.000 150000.000
# max   12345678.000            9999.000 19312.000 150000.000
#
#        monthOfRegistration  postalCode
# count            50001.000   50001.000
# mean                 5.744   50775.217
# std                  3.711   25743.702
# min                  0.000    1067.000
# 25%                  3.000   30559.000
# 50%                  6.000   49504.000
# 75%                  9.000   71404.000
# max                 12.000   99998.000

# %%
col = ['name', 'dateCrawled','dateCreated','postalCode','lastSeen']
cars=cars.drop(columns=col,axis=1)

# %%
cars.drop_duplicates(keep='first', inplace=True)

# %%
cars.isnull().sum()
# Out:
# seller                    0
# offerType                 0
# price                     0
# abtest                    0
# vehicleType            5152
# yearOfRegistration        0
# gearbox                2765
# powerPS                   0
# model                  2730
# kilometer                 0
# monthOfRegistration       0
# fuelType               4467
# brand                     0
# notRepairedDamage      9640
# dtype: int64

# %%
# Variable yearOfRegistration

# %%
yearwise_count=cars['yearOfRegistration'].value_counts().sort_index()
sum(cars['yearOfRegistration']>2018)
sum(cars['yearOfRegistration']<1950)
# Out:
# 38

# %%
sns.regplot(x='yearOfRegistration', y='price',
            fit_reg=False, data=cars)
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='price'>

# %%
# Variable price

# %%
price_count=cars['price'].value_counts().sort_index()
sns.displot(cars[cars['price'] < 10000]['price'])

# %%
sns.boxplot(y=cars['price'])
sum(cars['price']>150000)
sum(cars['price']<100)
# Out:
# 1748

# %%
powerPS_counts=cars['powerPS'].value_counts().sort_index()
sns.displot(cars['powerPS'])
cars['powerPS'].describe()
sns.boxplot(y=cars['powerPS'])
sns.regplot(x='powerPS', y='price',scatter=True,
            fit_reg=False, data=cars)
sum(cars['powerPS']>500)
sum(cars['powerPS']<10)
# Out:
# 5565

# %%
cars = cars[
     (cars['yearOfRegistration'] <= 2018)
   & (cars['yearOfRegistration'] >= 1950)
   & (cars['price'] <= 150000)
   & (cars['price'] >= 100)
   & (cars['powerPS'] <= 500)
   & (cars['powerPS'] >= 10)]

# %%
cars['monthOfRegistration']/=12

# %%
cars['Age'] = (2018-cars['yearOfRegistration'])+cars['monthOfRegistration']
cars['Age'] = round(cars['Age'],2)
cars['Age'].describe()
# Out:
# count   42772.000
# mean       14.873
# std         7.093
# min         0.000
# 25%        10.330
# 50%        14.830
# 75%        19.170
# max        67.750
# Name: Age, dtype: float64

# %%
col1 = ['yearOfRegistration','monthOfRegistration']
cars=cars.drop(columns=col1,axis=1)

# %%
sns.histplot(cars['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(y=cars['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.distplot(cars['price'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18316\3229821580.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(y=cars['price'])
# Out:
# <Axes: ylabel='price'>

# %%
sns.distplot(cars['powerPS'])
sns.boxplot(y=cars['powerPS'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18316\3051421491.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['powerPS'])
# <Axes: xlabel='powerPS', ylabel='Density'>

# %%
sns.regplot(x='Age', y='price',scatter=True,
            fit_reg=False, data=cars)
# Out:
# <Axes: xlabel='Age', ylabel='price'>

# %%
sns.regplot(x='powerPS', y='price',scatter=True,
            fit_reg=False, data=cars)
# Out:
# <Axes: xlabel='powerPS', ylabel='price'>

# %%
cars['seller'].value_counts()
# Out:
# seller
# private       42771
# commercial        1
# Name: count, dtype: int64

# %%
pd.crosstab(cars['seller'],columns='count',normalize=True)
# Out:
# col_0       count
# seller
# commercial  0.000
# private     1.000

# %%
sns.countplot(x= 'seller', data=cars)
# Out:
# <Axes: xlabel='seller', ylabel='count'>

# %%
cars['offerType'].value_counts()
# Out:
# offerType
# offer    42772
# Name: count, dtype: int64

# %%
sns.countplot(x= 'offerType', data=cars)
# Out:
# <Axes: xlabel='offerType', ylabel='count'>

# %%
cars['abtest'].value_counts()
# Out:
# abtest
# test       22128
# control    20644
# Name: count, dtype: int64

# %%
pd.crosstab(cars['abtest'],columns='count',normalize=True)
# Out:
# col_0    count
# abtest
# control  0.483
# test     0.517

# %%
sns.countplot(x= 'abtest', data=cars)
# Out:
# <Axes: xlabel='abtest', ylabel='count'>

# %%
sns.boxplot(x = 'abtest', y ='price', data=cars)
# Out:
# <Axes: xlabel='abtest', ylabel='price'>

# %%
cars['vehicleType'].value_counts()
# Out:
# vehicleType
# limousine        11746
# small car         9285
# station wagon     8076
# bus               3597
# cabrio            2792
# coupe             2261
# suv               1813
# others             326
# Name: count, dtype: int64

# %%
pd.crosstab(cars['vehicleType'],columns='count',normalize=True)
# Out:
# col_0          count
# vehicleType
# bus            0.090
# cabrio         0.070
# coupe          0.057
# limousine      0.294
# others         0.008
# small car      0.233
# station wagon  0.202
# suv            0.045

# %%
sns.countplot(x= 'vehicleType', data=cars)
# Out:
# <Axes: xlabel='vehicleType', ylabel='count'>

# %%
sns.boxplot(x = 'vehicleType', y ='price', data=cars)
# Out:
# <Axes: xlabel='vehicleType', ylabel='price'>

# %%
cars['gearbox'].value_counts()
# Out:
# gearbox
# manual       32582
# automatic     9396
# Name: count, dtype: int64

# %%
pd.crosstab(cars['gearbox'],columns='count',normalize=True)
# Out:
# col_0      count
# gearbox
# automatic  0.224
# manual     0.776

# %%
sns.countplot(x= 'gearbox', data=cars)
# Out:
# <Axes: xlabel='gearbox', ylabel='count'>

# %%
sns.boxplot(x = 'gearbox', y ='price', data=cars)
# Out:
# <Axes: xlabel='gearbox', ylabel='price'>

# %%
cars['model'].value_counts()
# Out:
# model
# golf          3478
# others        2900
# 3er           2482
# polo          1500
# corsa         1386
#               ...
# b_max            1
# serie_3          1
# elefantino       1
# charade          1
# rangerover       1
# Name: count, Length: 247, dtype: int64

# %%
pd.crosstab(cars['model'],columns='count',normalize=True)
# Out:
# col_0    count
# model
# 100      0.001
# 145      0.000
# 147      0.001
# 156      0.002
# 159      0.000
# ...        ...
# yaris    0.003
# yeti     0.001
# ypsilon  0.001
# z_reihe  0.003
# zafira   0.008
#
# [247 rows x 1 columns]

# %%
sns.countplot(x= 'model', data=cars)
# Out:
# <Axes: xlabel='model', ylabel='count'>

# %%
sns.boxplot(x = 'model', y ='price', data=cars)
# Out:
# <Axes: xlabel='model', ylabel='price'>

# %%
cars['kilometer'].value_counts()
# Out:
# kilometer
# 150000    27430
# 125000     4597
# 100000     1824
# 90000      1484
# 80000      1378
# 70000      1182
# 60000      1101
# 50000       932
# 40000       795
# 30000       712
# 20000       651
# 5000        479
# 10000       207
# Name: count, dtype: int64

# %%
pd.crosstab(cars['kilometer'],columns='count',normalize=True)
# Out:
# col_0      count
# kilometer
# 5000       0.011
# 10000      0.005
# 20000      0.015
# 30000      0.017
# 40000      0.019
# 50000      0.022
# 60000      0.026
# 70000      0.028
# 80000      0.032
# 90000      0.035
# 100000     0.043
# 125000     0.107
# 150000     0.641

# %%
sns.countplot(x= 'kilometer', data=cars)
# Out:
# <Axes: xlabel='kilometer', ylabel='count'>

# %%
sns.boxplot(x = 'kilometer', y ='price', data=cars)
# Out:
# <Axes: xlabel='kilometer', ylabel='price'>

# %%
cars['fuelType'].value_counts()
# Out:
# fuelType
# petrol     26509
# diesel     12854
# lpg          690
# cng           70
# hybrid        36
# electro       10
# other          6
# Name: count, dtype: int64

# %%
pd.crosstab(cars['fuelType'],columns='count',normalize=True)
# Out:
# col_0     count
# fuelType
# cng       0.002
# diesel    0.320
# electro   0.000
# hybrid    0.001
# lpg       0.017
# other     0.000
# petrol    0.660

# %%
sns.countplot(x= 'fuelType', data=cars)
# Out:
# <Axes: xlabel='fuelType', ylabel='count'>

# %%
sns.boxplot(x = 'fuelType', y ='price', data=cars)
# Out:
# <Axes: xlabel='fuelType', ylabel='price'>

# %%
cars['brand'].value_counts()
# Out:
# brand
# volkswagen        9134
# bmw               4868
# opel              4487
# mercedes_benz     4134
# audi              3984
# ford              2815
# renault           1941
# peugeot           1323
# fiat               996
# seat               886
# skoda              698
# mazda              663
# smart              623
# nissan             601
# citroen            598
# toyota             547
# volvo              429
# mini               428
# hyundai            406
# mitsubishi         359
# honda              300
# sonstige_autos     299
# kia                276
# suzuki             264
# porsche            260
# alfa_romeo         245
# chevrolet          213
# chrysler           151
# dacia              123
# subaru             112
# jeep                91
# land_rover          81
# jaguar              78
# daihatsu            67
# saab                65
# lancia              56
# rover               53
# daewoo              53
# trabant             43
# lada                22
# Name: count, dtype: int64

# %%
pd.crosstab(cars['brand'],columns='count',normalize=True)
# Out:
# col_0           count
# brand
# alfa_romeo      0.006
# audi            0.093
# bmw             0.114
# chevrolet       0.005
# chrysler        0.004
# citroen         0.014
# dacia           0.003
# daewoo          0.001
# daihatsu        0.002
# fiat            0.023
# ford            0.066
# honda           0.007
# hyundai         0.009
# jaguar          0.002
# jeep            0.002
# kia             0.006
# lada            0.001
# lancia          0.001
# land_rover      0.002
# mazda           0.016
# mercedes_benz   0.097
# mini            0.010
# mitsubishi      0.008
# nissan          0.014
# opel            0.105
# peugeot         0.031
# porsche         0.006
# renault         0.045
# rover           0.001
# saab            0.002
# seat            0.021
# skoda           0.016
# smart           0.015
# sonstige_autos  0.007
# subaru          0.003
# suzuki          0.006
# toyota          0.013
# trabant         0.001
# volkswagen      0.214
# volvo           0.010

# %%
sns.countplot(x= 'brand', data=cars)
# Out:
# <Axes: xlabel='brand', ylabel='count'>

# %%
sns.boxplot(x = 'brand', y ='price', data=cars)
# Out:
# <Axes: xlabel='brand', ylabel='price'>

# %%
cars['notRepairedDamage'].value_counts()
# Out:
# notRepairedDamage
# no     32507
# yes     3988
# Name: count, dtype: int64

# %%
pd.crosstab(cars['notRepairedDamage'],columns='count',normalize=True)
# Out:
# col_0              count
# notRepairedDamage
# no                 0.891
# yes                0.109

# %%
sns.countplot(x= 'notRepairedDamage', data=cars)
# Out:
# <Axes: xlabel='notRepairedDamage', ylabel='count'>

# %%
sns.boxplot(x = 'notRepairedDamage', y ='price', data=cars)
# Out:
# <Axes: xlabel='notRepairedDamage', ylabel='price'>

# %%
print(cars.columns)
# Out:
# Index(['price', 'vehicleType', 'gearbox', 'powerPS', 'model', 'kilometer',
#        'fuelType', 'brand', 'notRepairedDamage', 'Age'],
#       dtype='object')

# %%
cars_Select1=cars.select_dtypes(exclude=[object])

# %%
correlation=cars_Select1.corr()

# %%
round(correlation,3)
# Out:
#            price  powerPS  kilometer    Age
# price      1.000    0.575     -0.440 -0.336
# powerPS    0.575    1.000     -0.016 -0.151
# kilometer -0.440   -0.016      1.000  0.292
# Age       -0.336   -0.151      0.292  1.000

# %%
cars_Select1.corr().loc[:,'price'].abs().sort_values(ascending=False)[1:]
# Out:
# powerPS     0.575
# kilometer   0.440
# Age         0.336
# Name: price, dtype: float64

# %%
cars_omit=cars.dropna(axis=0)

# %%
cars_omit=pd.get_dummies(cars_omit,drop_first=True)

# %%
cars_omit.describe()
# Out:
#            price   powerPS  kilometer       Age
# count  32884.000 32884.000  32884.000 32884.000
# mean    6782.165   129.121 124043.760    15.020
# std     8288.544    60.749  39714.394     6.279
# min      100.000    10.000   5000.000     0.420
# 25%     1690.000    86.000 100000.000    10.500
# 50%     3999.000   116.000 150000.000    14.670
# 75%     8800.000   156.000 150000.000    18.920
# max   149000.000   500.000 150000.000    67.500

# %%
cars_omit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32884 entries, 1 to 50000
# Columns: 301 entries, price to notRepairedDamage_yes
# dtypes: bool(297), float64(1), int64(3)
# memory usage: 10.6 MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
#separating input and utput features

# %%
x1 = cars_omit.drop(['price'], axis='columns', inplace=False)
y1 = cars_omit['price']

# %%
#Plotting the valirable price

# %%
prices = pd.DataFrame({"1. Before":y1, "2. After":np.log(y1)})
prices.hist()
# Out:
# array([[<Axes: title={'center': '1. Before'}>,
#         <Axes: title={'center': '2. After'}>]], dtype=object)

# %%
#Tranformig price as a logtithmic value

# %%
y1=np.log(y1)

# %%
#splitting data into test and train

# %%
X_train, X_test, y_train, y_test = train_test_split(x1, y1, test_size=0.3, random_state = 3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (23018, 300) (9866, 300) (23018,) (9866,)

# %%
#Base line model for omitte data
""" we are making a base model by using test data mean value this is to set a benchmark and to compare with our regression model"""
# Out:
# ' we are making a base model by using test data mean value this is to set a benchmark and to compare with our regression model'

# %%
#finding the mean for test data value

# %%
base_pred = np.mean(y_test)
print(base_pred)
# Out:
# 0.7397996136833013

# %%
#REPEATING same value till length of test data

# %%
base_pred = np.repeat(base_pred, len(y_test))
print(base_pred)
# Out:
# [0.73979961 0.73979961 0.73979961 ... 0.73979961 0.73979961 0.73979961]

# %%
#finding the RMSE

# %%
base_root_mean_square_error = np.sqrt(mean_squared_error(y_test, base_pred))

# %%
#model

# %%
lgr = LinearRegression(fit_intercept=True)

# %%
model_lin1 = lgr.fit(X_train,y_train)

# %%
#prediction model on test set

# %%
cars_predictions_lin1 = lgr.predict(X_test)

# %%
#computing MSE and RMSE

# %%
lin_mse1 = mean_squared_error(y_test, cars_predictions_lin1)

# %%
line_rmse1 = np.sqrt(lin_mse1)

# %%
print(line_rmse1)
# Out:
# 0.03687863597969128

# %%
# R squared value

# %%
r2_lin_test1=model_lin1.score(X_test,y_test)
r2_lin_train1=model_lin1.score(X_train,y_train)
print(r2_lin_test1, r2_lin_train1)
# Out:
# 0.7140385171516876 0.7326275078901178

# %%
residuals1=y_test-cars_predictions_lin1

# %%
sns.regplot(x=cars_predictions_lin1, y=residuals1, scatter=True, fit_reg=False)
# Out:
# <Axes: ylabel='price'>

# %%
#RANDOM FOREST WITH OMITTED DATA

# %%
#model parameters

# %%
rf = RandomForestRegressor(n_estimators = 100, max_features='sqrt',
                           max_depth=100, min_samples_split=10, min_samples_leaf=4, random_state=1)

# %%
#model

# %%
model_rf1=rf.fit(X_train,y_train)

# %%
#prediction model on test set

# %%
cars_predictions_rf1  =rf.predict(X_test)

# %%
#comp;uting MSE and RMSE

# %%
rf_mse1 = mean_squared_error(y_test, cars_predictions_rf1)
rf_rmse1 = np.sqrt(rf_mse1)
print(rf_rmse1)
# Out:
# 0.03281776844134816

# %%
r2_rf_test1=model_rf1.score(X_test,y_test)
r2_rf_train1=model_rf1.score(X_train,y_train)
print(r2_rf_test1, r2_rf_train1)
# Out:
# 0.7735481181730613 0.8000508167172382

# %%
#MODEL BULDING WITH IMPUTED DATA

# %%
cars_imputed = cars.apply(
    lambda x: x.fillna(x.median()) if x.dtype=='float' else x.fillna(x.value_counts().index[0])
)
cars_imputed.isnull().sum()
# Out:
# price                0
# vehicleType          0
# gearbox              0
# powerPS              0
# model                0
# kilometer            0
# fuelType             0
# brand                0
# notRepairedDamage    0
# Age                  0
# dtype: int64

# %%
#converting categorical variables to dummy variables

# %%
cars_imputed=pd.get_dummies(cars_imputed,drop_first=True)

# %%
#model BULDING WITH IMPUTED DATA

# %%
#separating input and output feature

# %%
x2 = cars_imputed.drop(['price'], axis='columns', inplace=False)
y2 = cars_imputed['price']

# %%
#plotting the variable price

# %%
prices = pd.DataFrame({"1. Before":y2, "2. After":np.log(y2)})
prices.hist()
# Out:
# array([[<Axes: title={'center': '1. Before'}>,
#         <Axes: title={'center': '2. After'}>]], dtype=object)

# %%
y2=np.log(y2)

# %%
#splitting data into test and train

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(x2, y2, test_size=0.3, random_state = 3)
print(X_train1.shape, X_test1.shape, y_train1.shape, y_test1.shape)
# Out:
# (29940, 303) (12832, 303) (29940,) (12832,)

# %%
#BASELINE MODEL FOR IMPUTED DATA

# %%
base_pred = np.mean(y_test1)
print(base_pred)

base_pred = np.repeat(base_pred, len(y_test1))
print(base_pred)
# Out:
# 8.068391740519065
# [8.06839174 8.06839174 8.06839174 ... 8.06839174 8.06839174 8.06839174]

# %%
base_root_mean_square_error2 = np.sqrt(mean_squared_error(y_test1, base_pred))
print(base_root_mean_square_error2)
# Out:
# 1.1884349112889792

# %%
#LINEAR REGRESSION WITH IMPUTED DATA

# %%
#setting intercept as true

# %%
lgr2=LinearRegression(fit_intercept=True)

# %%
#model

# %%
model_lin2=lgr2.fit(X_train1, y_train1)

# %%
#predicting model on the test set

# %%
cars_predictions_lin2 = lgr2.predict(X_test1)

# %%
#computing MSE and RMSE

# %%
lin_mse2 = mean_squared_error(y_test1, cars_predictions_lin2)
lin_rmse2 = np.sqrt(lin_mse2)
print(lin_rmse2)
# Out:
# 0.6483956449231302

# %%
#R squared value

# %%
r2_lin_test2=model_lin2.score(X_test1,y_test1)
r2_lin_train2=model_lin2.score(X_train1,y_train1)
print(r2_lin_test2, r2_lin_train2)
# Out:
# 0.702333900863118 0.7071658736894363

# %%
#RANDOM FOREST WITH IMPUTED DATA

# %%
#Model parameters

# %%
rf2 = RandomForestRegressor(n_estimators = 100, max_features='sqrt',
                           max_depth=100, min_samples_split=10, min_samples_leaf=4, random_state=1)

# %%
model_rf2=rf2.fit(X_train1,y_train1)

# %%
cars_predictions_rf2  =rf2.predict(X_test1)

# %%
rf_mse2 = mean_squared_error(y_test1, cars_predictions_rf2)
rf_rmse2 = np.sqrt(rf_mse2)
print(rf_rmse2)
# Out:
# 0.5625193357650782

# %%
r2_rf_test2=model_rf2.score(X_test1,y_test1)
r2_rf_train2=model_rf2.score(X_train1,y_train1)
print(r2_rf_test2, r2_rf_train2)
# Out:
# 0.775960750923107 0.7998966387791918

# %%
print("Metrics for models built from data where missing values were omitted")
print("R squared value for train from Linear Regression= %s"% r2_lin_train1)
print("R squared value for test from Linear Regression= %s"% r2_lin_test1)
print("R squared value for train from Random Forest= %s"% r2_rf_train1)
print("R squared value for test from Random Forest= %s"% r2_rf_test1)
print("Base RMSE of model built from data where missing values were omitted= %s"%base_root_mean_square_error)
print("RMSE value for test from Linear Regression= %s"% line_rmse1)
print("RMSE value for test from Random Forest= %s"% rf_rmse1)
print("\n\n")
print("Metrics for models built from data where missing values were imputed")
print("R squared value for train from Linear Regression= %s"% r2_lin_train2)
print("R squared value for test from Linear Regression= %s"% r2_lin_test2)
print("R squared value for train from Random Forest= %s"% r2_rf_train2)
print("R squared value for test from Random Forest= %s"% r2_rf_test2)
print("Base RMSE of model built from data where missing values were imputed= %s"%base_root_mean_square_error)
print("RMSE value for test from Linear Regression= %s"% lin_rmse2)
print("RMSE value for test from Random Forest= %s"% rf_rmse2)
# Out:
# Metrics for models built from data where missing values were omitted
# R squared value for train from Linear Regression= 0.7326275078901178
# R squared value for test from Linear Regression= 0.7140385171516876
# R squared value for train from Random Forest= 0.8000508167172382
# R squared value for test from Random Forest= 0.7735481181730613
# Base RMSE of model built from data where missing values were omitted= 1.1884349112889792
# RMSE value for test from Linear Regression= 0.03687863597969128
# RMSE value for test from Random Forest= 0.03281776844134816
#
#
#
# Metrics for models built from data where missing values were imputed
# R squared value for train from Linear Regression= 0.7071658736894363
# R squared value for test from Linear Regression= 0.702333900863118
# R squared value for train from Random Forest= 0.7998966387791918
# R squared value for test from Random Forest= 0.775960750923107
# Base RMSE of model built from data where missing values were imputed= 1.1884349112889792
# RMSE value for test from Linear Regression= 0.6483956449231302
# RMSE value for test from Random Forest= 0.5625193357650782
